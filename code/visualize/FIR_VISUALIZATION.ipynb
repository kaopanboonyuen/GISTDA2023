# %% [markdown]
# # Fire Information Report
#
# Using GeoPandas to show heating up: Satellite imagery shows hotspots in and around northern Thailand.
#
# ![](https://github.com/kaopanboonyuen/GISTDA2023/raw/main/img/FIR_logo2.jpeg)

# %%
# !pip install folium >> tmp
# !pip install geopandas >> tmp

# %%
# !wget https://github.com/kaopanboonyuen/GISTDA2023/raw/main/dataset/202202_FEB_FIR_SHP.zip

# %%
# !unzip 202202_FEB_FIR_SHP.zip >> tmp

# %% [markdown]
# # Data Sample

# %%
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")
# Read the shapefile

shapefile_path = "202202_FEB_FIR_SHP/20220214_FIR_SHP/20220214_FIR_SHP.shp"
gdf = gpd.read_file(shapefile_path)

transformed_gdfs = []
transformed_gdfs.append(gdf)

# Convert the GeoDataFrame to a DataFrame
df = gdf.drop(columns="geometry")

# Display the DataFrame
df.head()
# Out:
#   NAME                           GM_LAYER                GM_TYPE  \
# 0   1J  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature
# 1   1L  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature
# 2   1K  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature
# 3   1R     J1_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature
# 4   1N  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature
#
#                      MAP_NAME  LATITUDE  LONGITUDE NUMBER   DISTRICT  \
# 0  Province_FIR_1_3_9_SHP.shp  18.56364   98.31892     1J  Mae Chaem
# 1  Province_FIR_1_3_9_SHP.shp  18.48861   98.34169     1L  Mae Chaem
# 2  Province_FIR_1_3_9_SHP.shp  18.50445   98.40274     1K  Mae Chaem
# 3  Province_FIR_1_3_9_SHP.shp  18.23130   98.42541     1R        Hot
# 4  Province_FIR_1_3_9_SHP.shp  18.25719   98.54907     1N  Chomthong
#
#      PROVINCE PRIORITY  ...  POINT_SYMB        FONT_NAME  FONT_SIZE  \
# 0  CHIANG MAI        *  ...   Dot - Red  Times New Roman       10.0
# 1  CHIANG MAI        *  ...   Dot - Red  Times New Roman       10.0
# 2  CHIANG MAI        *  ...   Dot - Red  Times New Roman       10.0
# 3  CHIANG MAI        *  ...   Dot - Red  Times New Roman       10.0
# 4  CHIANG MAI        *  ...   Dot - Red  Times New Roman       10.0
#
#    FONT_COLOR  FONT_STYLE FONT_CHARS FONT_WEIGH POINT_SYM1  FONT_CHAR1  \
# 0  RGB(0,0,0)     OPAQUE,        1.0      400.0        NaN         NaN
# 1  RGB(0,0,0)     OPAQUE,        1.0      400.0        NaN         NaN
# 2  RGB(0,0,0)     OPAQUE,        1.0      400.0        NaN         NaN
# 3  RGB(0,0,0)     OPAQUE,        1.0      400.0        NaN         NaN
# 4  RGB(0,0,0)     OPAQUE,        1.0      400.0        NaN         NaN
#
#    FONT_WEIG1
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # Import Data using GeoPandas: (1 Month: Feb/2022)

# %%
import os
import geopandas as gpd
import pandas as pd

# Root directory containing all folders with shapefiles
root_dir = "202202_FEB_FIR_SHP/"

# Initialize an empty list to store GeoDataFrames
gdfs = []

# Recursive function to search for shapefiles and combine them
def search_shapefiles(folder):
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(".shp"):
                # Read the shapefile and append to the list
                shapefile_path = os.path.join(root, file)
                gdf = gpd.read_file(shapefile_path)
                if gdf.crs != transformed_gdfs[0].crs:
                  # Transform the CRS to match the first GeoDataFrame
                  gdf = gdf.to_crs(transformed_gdfs[0].crs)

                transformed_gdfs.append(gdf)
                gdfs.append(gdf)
                
        for dir in dirs:
            # Recursively search in subfolders
            search_shapefiles(os.path.join(root, dir))

# Start the search from the root directory
search_shapefiles(root_dir)

# Combine all GeoDataFrames into a single DataFrame
combined_df = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

# Display the combined DataFrame

combined_df.head()
# Out:
#   NAME                           GM_LAYER                GM_TYPE  LATITUDE  \
# 0   2A  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature  19.35221
# 1  11A  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature  15.50836
# 2  11B  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature  15.41239
# 3   1C     J1_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature  18.82367
# 4   1D  SUOMI_VIIRS_C2_SouthEast_Asia_24h  Unknown Point Feature  18.37741
#
#    LONGITUDE      BRIGHT_TI4  SCAN  TRACK   ACQ_DATE ACQ_TIME  ... PIORITY  \
# 0   97.98300          334.65  0.42   0.37  2/18/2022     0650  ...     NaN
# 1  101.16861          336.68  0.53   0.42  2/18/2022     0648  ...     NaN
# 2  101.22559          304.96  0.45   0.39  2/19/2022     1902  ...     NaN
# 3   98.11649  303.9700000000  0.40   0.60  2/14/2022     1944  ...     NaN
# 4   98.26976  353.2900000000  0.51   0.41  2/14/2022     0624  ...     NaN
#
#   PROVICE NUMBER  PROVINC  Piority KML_STYLE ELEVATION DISTRICR TAGET TAEGET
# 0     NaN    NaN      NaN      NaN       NaN       NaN      NaN   NaN    NaN
# 1     NaN    NaN      NaN      NaN       NaN       NaN      NaN   NaN    NaN
# 2     NaN    NaN      NaN      NaN       NaN       NaN      NaN   NaN    NaN
# 3     NaN    NaN      NaN      NaN       NaN       NaN      NaN   NaN    NaN
# 4     NaN    NaN      NaN      NaN       NaN       NaN      NaN   NaN    NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
combined_df.columns
# Out:
# Index(['NAME', 'GM_LAYER', 'GM_TYPE', 'LATITUDE', 'LONGITUDE', 'BRIGHT_TI4',
#        'SCAN', 'TRACK', 'ACQ_DATE', 'ACQ_TIME', 'SATELLITE', 'CONFIDENCE',
#        'VERSION', 'BRIGHT_TI5', 'FRP', 'DAYNIGHT', 'layer', 'path', 'LAYER_2',
#        'MAP_NAME', 'Shape_Leng', 'Shape_Area', 'TAMBON_EN', 'TAMBON_PCO',
#        'ADM3_REF', 'ADM3ALT1EN', 'ADM3ALT2EN', 'ADM3ALT1TH', 'ADM3ALT2TH',
#        'DISTRIC_EN', 'DISTRIC_PC', 'PROVINC_EN', 'PROVINC_PC', 'NATION_EN',
#        'NATION_PCO', 'date', 'validOn', 'validTo', 'PRIORITY', 'TRAGET',
#        'AREA', 'POINT_SYMB', 'FONT_NAME', 'FONT_SIZE', 'FONT_COLOR',
#        'FONT_STYLE', 'FONT_CHARS', 'FONT_WEIGH', 'geometry', 'POINT_SYM1',
#        'FONT_CHAR1', 'FONT_WEIG1', 'PROVING', 'DISTRICT', 'TARGET', 'PROVINCE',
#        'LAYER', 'AREA_EN', 'AREA_TH', 'LAT', 'LON', 'TAMBON_TH', 'DISTRIC_TH',
#        'PROVINC_TH', 'NATION_TH', 'FONT_PLACE', 'PIORITY', 'PROVICE', 'NUMBER',
#        'PROVINC', 'Piority', 'KML_STYLE', 'ELEVATION', 'DISTRICR', 'TAGET',
#        'TAEGET'],
#       dtype='object')

# %%
combined_df_2 = combined_df[['ACQ_DATE','LATITUDE','LONGITUDE','BRIGHT_TI4','CONFIDENCE',
       'SCAN', 'TRACK','DISTRIC_EN','PROVINC_EN','SATELLITE','TRAGET']]

combined_df_2.head(5)
# Out:
#     ACQ_DATE  LATITUDE  LONGITUDE      BRIGHT_TI4 CONFIDENCE  SCAN  TRACK  \
# 0  2/18/2022  19.35221   97.98300          334.65    nominal  0.42   0.37
# 1  2/18/2022  15.50836  101.16861          336.68    nominal  0.53   0.42
# 2  2/19/2022  15.41239  101.22559          304.96    nominal  0.45   0.39
# 3  2/14/2022  18.82367   98.11649  303.9700000000    nominal  0.40   0.60
# 4  2/14/2022  18.37741   98.26976  353.2900000000    nominal  0.51   0.41
#
#             DISTRIC_EN    PROVINC_EN SATELLITE TRAGET
# 0  Mueang Mae Hong Son  Mae Hong Son         N     2A
# 1              Si Thep    Phetchabun         N    11A
# 2              Si Thep    Phetchabun         N    11B
# 3            Mae Chaem    Chiang Mai         1     1C
# 4            Mae Chaem    Chiang Mai         N     1D

# %%
combined_df_2['ACQ_DATE'] = pd.to_datetime(combined_df_2['ACQ_DATE'])

# %%
combined_df_2.CONFIDENCE.value_counts()
# Out:
# nominal    2248
# high         60
# Name: CONFIDENCE, dtype: int64

# %%
combined_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ACQ_DATE    2308 non-null   datetime64[ns]
#  1   LATITUDE    2308 non-null   float64
#  2   LONGITUDE   2308 non-null   float64
#  3   BRIGHT_TI4  2308 non-null   object
#  4   CONFIDENCE  2308 non-null   object
#  5   SCAN        2168 non-null   float64
#  6   TRACK       2168 non-null   float64
#  7   DISTRIC_EN  1738 non-null   object
#  8   PROVINC_EN  1738 non-null   object
#  9   SATELLITE   2308 non-null   object
#  10  TRAGET      264 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 232.8+ KB

# %% [markdown]
# # Convert Data Type

# %%
combined_df_2['BRIGHT_TI4'] = combined_df_2['BRIGHT_TI4'].astype(str).astype(float)

# %% [markdown]
# # Descriptive Statistics

# %%
combined_df_2.describe() # include='all'
# Out:
#           LATITUDE    LONGITUDE   BRIGHT_TI4         SCAN        TRACK
# count  2308.000000  2308.000000  2308.000000  2168.000000  2168.000000
# mean     18.076143    99.238594   329.931750     0.457057     0.474982
# std       1.255834     1.074736    17.896872     0.084335     0.114823
# min      15.380640    97.360570   300.010000     0.320000     0.360000
# 25%      17.124310    98.401380   309.640000     0.390000     0.370000
# 50%      18.559420    98.870950   335.350000     0.440000     0.440000
# 75%      19.004450   100.081440   342.110000     0.510000     0.550000
# max      20.041350   101.470440   367.000000     0.780000     0.780000

# %%
combined_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ACQ_DATE    2308 non-null   datetime64[ns]
#  1   LATITUDE    2308 non-null   float64
#  2   LONGITUDE   2308 non-null   float64
#  3   BRIGHT_TI4  2308 non-null   float64
#  4   CONFIDENCE  2308 non-null   object
#  5   SCAN        2168 non-null   float64
#  6   TRACK       2168 non-null   float64
#  7   DISTRIC_EN  1738 non-null   object
#  8   PROVINC_EN  1738 non-null   object
#  9   SATELLITE   2308 non-null   object
#  10  TRAGET      264 non-null    object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 232.8+ KB

# %% [markdown]
# # Clean and Feature Selection

# %%
combined_df_2.isnull().sum()
# Out:
# ACQ_DATE       400
# LATITUDE       400
# LONGITUDE      400
# BRIGHT_TI4     400
# CONFIDENCE     400
# SCAN           540
# TRACK          540
# DISTRIC_EN     970
# PROVINC_EN     970
# SATELLITE      400
# TRAGET        2444
# dtype: int64

# %%
combined_df_2.shape
# Out:
# (2708, 11)

# %% [markdown]
# # Select Rows Based on column Values (BRIGHT_TI4 & CONFIDENCE)

# %%
combined_df_3 = combined_df_2.loc[combined_df_2['BRIGHT_TI4'] >= 200]
combined_df_3 = combined_df_3.loc[(combined_df_3['CONFIDENCE'] == 'nominal') | (combined_df_3['CONFIDENCE'] == 'high')]

# %%
combined_df_3.shape
# Out:
# (2308, 11)

# %%
combined_df_3 = combined_df_3.dropna()

# %%
combined_df_3.isnull().sum()
# Out:
# ACQ_DATE      0
# LATITUDE      0
# LONGITUDE     0
# BRIGHT_TI4    0
# CONFIDENCE    0
# SCAN          0
# TRACK         0
# DISTRIC_EN    0
# PROVINC_EN    0
# SATELLITE     0
# TRAGET        0
# dtype: int64

# %%
combined_df_3['ACQ_DATE'].value_counts()
# Out:
# 2022-02-14    118
# 2022-02-13     86
# 2022-02-16     32
# 2022-02-15     10
# 2022-02-18      8
# 2022-02-17      8
# 2022-02-19      2
# Name: ACQ_DATE, dtype: int64

# %% [markdown]
# # Save .csv file

# %%
combined_df_3.to_csv('FIR_SAMPLE_OUTPUT.csv')

# %% [markdown]
# # Data Visualization using Folium (Whole Month)

# %%
import pandas as pd
import folium

# Create a DataFrame from the dataset
df = combined_df_3

# Convert 'ACQ_DATE' column to datetime
df['ACQ_DATE'] = pd.to_datetime(df['ACQ_DATE'])

# Create a map centered on Thailand
m = folium.Map(location=[13.736717, 100.523186], zoom_start=6)

# Add markers for each data point
for index, row in df.iterrows():
    folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=f"Date: {row['ACQ_DATE'].strftime('%m/%d/%Y')}<br>Target: {row['TRAGET']}",
        icon=folium.Icon(color='red')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a1c3c7e7914f39fe41a0342652b5901 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a1c3c7e7914f39fe41a0342652b5901&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a1c3c7e7914f39fe41a0342652b5901 = L.map(
#                 &quot;map_9a1c3c7e7914f39fe41a0342652b5901&quot;,
#                 {
#                     center: [13.736717, 100.523186],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_960c93eb6bf032401208fd49680e074a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a1c3c7e7914f39fe41a0342652b5901);
#
#
#             var marker_dad98a7079c4c7f05f8e887356c93905 = L.marker(
#                 [19.35221, 97.983],
#                 {}
#             ).addTo(map_9a1c3c7e7914f39fe41a0342652b5901);
#
#
#             var icon_c26fc9a76307ba6cf910f72220256c57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dad98a7079c4c7f05f8e887356c93905.setIcon(icon_c26fc9a76307ba6cf910f72220256c57);
#
#
#         var popup_8392194fca7dd136d2b9fda1010ffa1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fadd807e57d8099180c5abe01a7c8f4 = $(`&lt;div id=&quot;html_9fadd807e57d8099180c5abe01a7c8f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/18/2022&lt;br&gt;Target: 2A&lt;/div&gt;`)[0];
#                 popup_8392194fca7dd136d2b9fda1010ffa1d.setContent(html_9fadd807e57d8099180c5abe01a7c8f4);
#
#
#
#         marker_dad98a7079c4c7f05f8e887356c93905.bindPopup(popup_8392194fca7dd136d2b9fda1010ffa1d)
#         ;
#
#
#
#
#             var marker_de12bb361e09aa971c1ae23c905f39e0 = L.marker(
#                 [15.50836, 101.16861],
#                 {}
#             ).addTo(map_9a1c3c7e7914f39fe41a0342652b5901);
#
#
#             var icon_59d5ec9f19e4a8cdcdaa0a3a936cd16f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de12bb361e09aa971c1ae23c905f39e0.setIcon(icon_59d5ec9f19e4a8cdcdaa0a3a936cd16f);
#
#
#         var popup_15a37ae7b9305775ef113282b73a3fa4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed1b02523aeef9975a34a39a81418a2f = $(`&lt;div id=&quot;html_ed1b02523aeef9975a34a39a81418a2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/18/2022&lt;br&gt;Target: 11A&lt;/div&gt;`)[0];
#                 popup_15a37ae7b9305775ef113282b73a3fa4.setContent(html_ed1b02523aeef9975a34a39a81418a2f);
#
#
#
#         marker_de12bb361e09aa971c1ae23c905f39e0.bindPopup(popup_15a37ae7b9305775ef113282b73a3fa4)
#         ;
#
#
#
#
#             var marker_1ebdac324792a42b0e2bf754426033f9 = L.marker(
#                 [15.41239, 101.22559],
#                 {}
#             ).addTo(map_9a1c3c7e7914f39fe41a0342652b5901);
#
#
#             var icon_efe22362a404d3bf2f27acef7ab0e952 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ebdac324792a42b0e2bf754426033f9.setIcon(icon_efe22362a404d3bf2f27acef7ab0e952);
#
#
#         var popup_fc3c9e4552ba97281047dc9ac582dedf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_634aca73488e8486ba22e3e56f476a16 = $(`&lt;div id=&quot;html_634aca73488e8486ba22e3e56f476a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/19/2022&lt;br&gt;Target: 11B&lt;/div&gt;`)[0];
#                 popup_fc3c9e4552ba97281047dc9ac582dedf.setContent(html_634aca73488e8486ba22e3e56f476a16);
#
#
#
#         marker_1ebdac324792a42b0e2bf754426033f9.bindPopup(popup_fc3c9e4552ba97281047dc9ac582dedf)
#         ;
#
#
#
#
#             var marker_b16a60ec5f66c2a4c96803f23040ad8b = L.marker(
#                 [18.82367, 98.11649],
#                 {}
#             ).addTo(map_9a1c3c7e7914f39fe41a0342652b5901);
#
#
#             var icon_c87e4ba160ea529b5b3a0c8c24697bf7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasse

# %% [markdown]
# # Data Visualization using Folium (1 Day)

# %%
import pandas as pd
import folium

# Create a DataFrame from the dataset
df = combined_df_3

# Convert 'ACQ_DATE' column to datetime
df['ACQ_DATE'] = pd.to_datetime(df['ACQ_DATE'])

# Set the target date for filtering
target_date = pd.to_datetime('2/13/2022') # '2/13/2022', '2/14/2022', '2/15/2022', '2/16/2022'

# Create a map centered on Thailand
m = folium.Map(location=[13.736717, 100.523186], zoom_start=6)

# Add markers for each data point matching the target date
filtered_df = df[df['ACQ_DATE'] == target_date]
for index, row in filtered_df.iterrows():
    folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=f"Date: {row['ACQ_DATE'].strftime('%m/%d/%Y')}<br>Target: {row['TRAGET']}",
        icon=folium.Icon(color='red')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9be223dab453cf3e85a5ff1eaaf30d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9be223dab453cf3e85a5ff1eaaf30d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9be223dab453cf3e85a5ff1eaaf30d9 = L.map(
#                 &quot;map_a9be223dab453cf3e85a5ff1eaaf30d9&quot;,
#                 {
#                     center: [13.736717, 100.523186],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_118d611c43f016ba1cf1123e8249e89e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9be223dab453cf3e85a5ff1eaaf30d9);
#
#
#             var marker_aaf2b82fb470c4957d9c515033ee631c = L.marker(
#                 [19.05542, 99.67451],
#                 {}
#             ).addTo(map_a9be223dab453cf3e85a5ff1eaaf30d9);
#
#
#             var icon_686662a06299a7e18f0efe83db675736 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aaf2b82fb470c4957d9c515033ee631c.setIcon(icon_686662a06299a7e18f0efe83db675736);
#
#
#         var popup_2396dc85920f232fb5e5f7919bbf8499 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf19eb2597db3f265a3169e7165913c0 = $(`&lt;div id=&quot;html_cf19eb2597db3f265a3169e7165913c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/13/2022&lt;br&gt;Target: 7A&lt;/div&gt;`)[0];
#                 popup_2396dc85920f232fb5e5f7919bbf8499.setContent(html_cf19eb2597db3f265a3169e7165913c0);
#
#
#
#         marker_aaf2b82fb470c4957d9c515033ee631c.bindPopup(popup_2396dc85920f232fb5e5f7919bbf8499)
#         ;
#
#
#
#
#             var marker_5de0365391bb25278047921154d506ac = L.marker(
#                 [18.86832, 99.72678],
#                 {}
#             ).addTo(map_a9be223dab453cf3e85a5ff1eaaf30d9);
#
#
#             var icon_6362d0bf16141617bb7a7f495e8d0146 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5de0365391bb25278047921154d506ac.setIcon(icon_6362d0bf16141617bb7a7f495e8d0146);
#
#
#         var popup_bff6d3b9b6c147106951e61190254b5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ad7e8da59a112cdf80cc6d899921b84 = $(`&lt;div id=&quot;html_4ad7e8da59a112cdf80cc6d899921b84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/13/2022&lt;br&gt;Target: 7B&lt;/div&gt;`)[0];
#                 popup_bff6d3b9b6c147106951e61190254b5c.setContent(html_4ad7e8da59a112cdf80cc6d899921b84);
#
#
#
#         marker_5de0365391bb25278047921154d506ac.bindPopup(popup_bff6d3b9b6c147106951e61190254b5c)
#         ;
#
#
#
#
#             var marker_17ba746a6575c876e81b42b2535a5b1d = L.marker(
#                 [18.83869, 100.05894],
#                 {}
#             ).addTo(map_a9be223dab453cf3e85a5ff1eaaf30d9);
#
#
#             var icon_b45a42fe2940fef41326b8713fad87f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17ba746a6575c876e81b42b2535a5b1d.setIcon(icon_b45a42fe2940fef41326b8713fad87f1);
#
#
#         var popup_f5c1cf3ebee74b03fd93494af4bb4943 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a479bd6a3634190df931f97e9c3028d0 = $(`&lt;div id=&quot;html_a479bd6a3634190df931f97e9c3028d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 02/13/2022&lt;br&gt;Target: 7E&lt;/div&gt;`)[0];
#                 popup_f5c1cf3ebee74b03fd93494af4bb4943.setContent(html_a479bd6a3634190df931f97e9c3028d0);
#
#
#
#         marker_17ba746a6575c876e81b42b2535a5b1d.bindPopup(popup_f5c1cf3ebee74b03fd93494af4bb4943)
#         ;
#
#
#
#
#             var marker_19246bc2cad86d2033ae21748dda53b6 = L.marker(
#                 [18.80032, 99.98793],
#                 {}
#             ).addTo(map_a9be223dab453cf3e85a5ff1eaaf30d9);
#
#
#             var icon_6f4325b9fca097d84f904b202cdac674 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses
